# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamAmin05/AI-YOLOV5/blob/main/YoloV5SelfTrainFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using your own data for training in YoloV5
#
#
#
# 1.   Gather your data (organize into folder hierachy)
# 2.   Add labels to your data
# 3.   Edit YAML file to support the number of classes in your data along with labels of your data
# 4. Upload your data to Colab
# 5. Train model on your data using yaml file you configured
# 6. Test away!
#
# Tip:
# Reccomended training epochs - at least 100 (retrain with more epochs if you feel it could be more accurate!)

# %%
# clone the repository for the yolov5 folder
# !git clone https://github.com/ultralytics/yolov5.git

# change path (makes next line of code easier)
# %cd yolov5/

# install dependencies
# !pip install -U -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12176, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 12176 (delta 0), reused 2 (delta 0), pack-reused 12173
# Receiving objects: 100% (12176/12176), 11.96 MiB | 18.87 MiB/s, done.
# Resolving deltas: 100% (8428/8428), done.
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.7 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 39.4 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 805 kB/s
# ...
#      |████████████████████████████████| 793 kB 50.6 MB/s
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !unzip -q ../train_data2.zip -d ../

# %%
# !pip install wandb
import wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 181 kB 45.5 MB/s
# ...
#      |████████████████████████████████| 145 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=3de15c2d593c6777e668725742ad540791b85739357ef006a11ddbaae0b1a92e
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 700 --batch 20 --epochs 100 --data custom_data_2.yaml --weights yolov5s.pt --patience 100 --nosave --cache
# Out:
# wandb: Currently logged in as: shivamamin. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=custom_data_2.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=20, imgsz=700, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-244-g47233e1 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# ...

# %%
import time 
time.sleep(14400)

# %%
# !python detect.py --source /content/cats.jpeg --weights /content/yolov5/runs/train/exp7/weights/last.pt --conf 0.5
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/last.pt'], source=/content/cats.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-244-g47233e1 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/cats.jpeg: 352x640 Done. (0.244s)
# Speed: 2.6ms pre-process, 243.7ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !python detect.py --source /content/Dog_21.jpeg --weights runs/train/exp7/weights/last.pt
# Out:
# detect: weights=['runs/train/exp7/weights/last.pt'], source=/content/Dog_21.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-244-g47233e1 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Dog_21.jpeg: 448x640 1 cat, Done. (0.345s)
# Speed: 5.5ms pre-process, 345.0ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp13
